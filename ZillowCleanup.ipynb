# %%
import pandas as pd

# %%
df=pd.read_csv('Resources/City_Zhvi_AllHomes.csv')

# %%
df
# Out:
#        Unnamed: 0  RegionID  SizeRank   RegionName RegionType StateName State  \
# 0               0      6181         0     New York       City        NY    NY
# 1               1     12447         1  Los Angeles       City        CA    CA
# 2               2     39051         2      Houston       City        TX    TX
# 3               3     17426         3      Chicago       City        IL    IL
# 4               4      6915         4  San Antonio       City        TX    TX
# ...           ...       ...       ...          ...        ...       ...   ...
# 27325       27325     48550     29449       Winton       City        MN    MN
# 27326       27326     51821     29449  Eastabuchie       City        MS    MS
# 27327       27327    232607     29449         Dean       City        TX    TX
# 27328       27328      6638     29449      Pulaski       City        GA    GA
# 27329       27329     33089     29449    New Paris       City        PA    PA
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# RegionID        int64
# SizeRank        int64
# RegionName     object
# RegionType     object
#                ...
# 2019-11-30    float64
# 2019-12-31    float64
# 2020-01-31    float64
# 2020-02-29    float64
# 2020-03-31    float64
# Length: 300, dtype: object

# %%
df.set_index(['Unnamed: 0','RegionID','SizeRank','RegionName','RegionType','StateName','State','Metro','CountyName'], inplace=True)

# %%
df = df.stack().reset_index()

# %%
df
# Out:
#          Unnamed: 0  RegionID  SizeRank RegionName RegionType StateName State  \
# 0                 0      6181         0   New York       City        NY    NY
# 1                 0      6181         0   New York       City        NY    NY
# 2                 0      6181         0   New York       City        NY    NY
# 3                 0      6181         0   New York       City        NY    NY
# 4                 0      6181         0   New York       City        NY    NY
# ...             ...       ...       ...        ...        ...       ...   ...
# 5907651       27329     33089     29449  New Paris       City        PA    PA
# 5907652       27329     33089     29449  New Paris       City        PA    PA
# 5907653       27329     33089     29449  New Paris       City        PA    PA
# 5907654       27329     33089     29449  New Paris       City        PA    PA
# 5907655       27329     33089     29449  New Paris       City        PA    PA
#
# ...

# %%
df.rename(columns = {'level_9':'Date', df.columns[10]:'Price'}, inplace = True)

# %%
df
# Out:
#          Unnamed: 0  RegionID  SizeRank RegionName RegionType StateName State  \
# 0                 0      6181         0   New York       City        NY    NY
# 1                 0      6181         0   New York       City        NY    NY
# 2                 0      6181         0   New York       City        NY    NY
# 3                 0      6181         0   New York       City        NY    NY
# 4                 0      6181         0   New York       City        NY    NY
# ...             ...       ...       ...        ...        ...       ...   ...
# 5907651       27329     33089     29449  New Paris       City        PA    PA
# 5907652       27329     33089     29449  New Paris       City        PA    PA
# 5907653       27329     33089     29449  New Paris       City        PA    PA
# 5907654       27329     33089     29449  New Paris       City        PA    PA
# 5907655       27329     33089     29449  New Paris       City        PA    PA
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of          Unnamed: 0  RegionID  SizeRank RegionName RegionType StateName State  \
# 0                 0      6181         0   New York       City        NY    NY
# 1                 0      6181         0   New York       City        NY    NY
# 2                 0      6181         0   New York       City        NY    NY
# 3                 0      6181         0   New York       City        NY    NY
# 4                 0      6181         0   New York       City        NY    NY
# ...             ...       ...       ...        ...        ...       ...   ...
# 5907651       27329     33089     29449  New Paris       City        PA    PA
# 5907652       27329     33089     29449  New Paris       City        PA    PA
# 5907653       27329     33089     29449  New Paris       City        PA    PA
# 5907654       27329     33089     29449  New Paris       City        PA    PA
# 5907655       27329     33089     29449  New Paris       City        PA    PA
#
# ...

# %%
tn_only = df['State'] == 'TN'
df_tn = df.loc[tn_only]
df_tn
# Out:
#          Unnamed: 0  RegionID  SizeRank RegionName RegionType StateName State  \
# 7074             25     32811        25    Memphis       City        TN    TN
# 7075             25     32811        25    Memphis       City        TN    TN
# 7076             25     32811        25    Memphis       City        TN    TN
# 7077             25     32811        25    Memphis       City        TN    TN
# 7078             25     32811        25    Memphis       City        TN    TN
# ...             ...       ...       ...        ...        ...       ...   ...
# 5906196       27318     32351     29449  La Grange       City        TN    TN
# 5906197       27318     32351     29449  La Grange       City        TN    TN
# 5906198       27318     32351     29449  La Grange       City        TN    TN
# 5906199       27318     32351     29449  La Grange       City        TN    TN
# 5906200       27318     32351     29449  La Grange       City        TN    TN
#
# ...

# %%
df_tn.dtypes
# Out:
# Unnamed: 0      int64
# RegionID        int64
# SizeRank        int64
# RegionName     object
# RegionType     object
# StateName      object
# State          object
# Metro          object
# CountyName     object
# Date           object
# Price         float64
# dtype: object

# %%
df_tn['Date']= pd.to_datetime(df_tn['Date'])
# Out:
# C:\Users\Tommy\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_tn.dtypes
# Out:
# Unnamed: 0             int64
# RegionID               int64
# SizeRank               int64
# RegionName            object
# RegionType            object
# StateName             object
# State                 object
# Metro                 object
# CountyName            object
# Date          datetime64[ns]
# Price                float64
# dtype: object

# %%
df_tn_date = df_tn.loc[(df_tn['Date'] >= '2010-01-01')]

# %%
df_tn_date
# Out:
#          Unnamed: 0  RegionID  SizeRank RegionName RegionType StateName State  \
# 7242             25     32811        25    Memphis       City        TN    TN
# 7243             25     32811        25    Memphis       City        TN    TN
# 7244             25     32811        25    Memphis       City        TN    TN
# 7245             25     32811        25    Memphis       City        TN    TN
# 7246             25     32811        25    Memphis       City        TN    TN
# ...             ...       ...       ...        ...        ...       ...   ...
# 5906196       27318     32351     29449  La Grange       City        TN    TN
# 5906197       27318     32351     29449  La Grange       City        TN    TN
# 5906198       27318     32351     29449  La Grange       City        TN    TN
# 5906199       27318     32351     29449  La Grange       City        TN    TN
# 5906200       27318     32351     29449  La Grange       City        TN    TN
#
# ...
