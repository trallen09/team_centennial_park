# %%
# import dependancies
import pandas as pd

# %%
# read in csv
csv = pd.read_csv('Resources/Sale_Prices_City.csv')
sale_price_df = pd.DataFrame(csv)
sale_price_df.head()
# Out:
#    Unnamed: 0  RegionID   RegionName   StateName  SizeRank   2008-03  \
# 0           0      6181     New York    New York         1       NaN
# 1           1     12447  Los Angeles  California         2  507600.0
# 2           2     39051      Houston       Texas         3  138400.0
# 3           3     17426      Chicago    Illinois         4  325100.0
# 4           4      6915  San Antonio       Texas         5  130900.0
#
#     2008-04   2008-05   2008-06   2008-07  ...   2019-06   2019-07   2019-08  \
# 0       NaN       NaN       NaN       NaN  ...  563200.0  570500.0  572800.0
# 1  489600.0  463000.0  453100.0  438100.0  ...  706800.0  711800.0  717300.0
# 2  135500.0  132200.0  131000.0  133400.0  ...  209700.0  207400.0  207600.0
# 3  314800.0  286900.0  274600.0  268500.0  ...  271500.0  266500.0  264900.0
# 4  131300.0  131200.0  131500.0  131600.0  ...  197100.0  198700.0  200200.0
#
#     2019-09   2019-10   2019-11   2019-12   2020-01   2020-02   2020-03
# ...

# %%
#find dtypes
sale_price_df.dtypes
# Out:
# Unnamed: 0      int64
# RegionID        int64
# RegionName     object
# StateName      object
# SizeRank        int64
#                ...
# 2019-11       float64
# 2019-12       float64
# 2020-01       float64
# 2020-02       float64
# 2020-03       float64
# Length: 150, dtype: object

# %%
# filter data by state
tn_sale_df= sale_price_df.loc[sale_price_df['StateName'].isin(['Tennessee'])]
tn_sale_df.head()
# Out:
#      Unnamed: 0  RegionID    RegionName  StateName  SizeRank   2008-03  \
# 24           24     32811       Memphis  Tennessee        25       NaN
# 28           28      6118     Nashville  Tennessee        29  148900.0
# 50           50     25428     Knoxville  Tennessee        51  137000.0
# 159         159     37837   Chattanooga  Tennessee       160  107100.0
# 161         161     19523  Murfreesboro  Tennessee       162  140000.0
#
#       2008-04   2008-05   2008-06   2008-07  ...   2019-06   2019-07  \
# 24        NaN       NaN       NaN       NaN  ...  100700.0  102700.0
# 28   147200.0  146100.0  147600.0  147400.0  ...  270900.0  270300.0
# 50   137700.0  139800.0  138000.0  134900.0  ...  181400.0  179200.0
# 159  104600.0  108500.0  106000.0  107400.0  ...  169900.0  172100.0
# 161  142300.0  142000.0  138700.0  134800.0  ...  251900.0  252200.0
#
#       2019-08   2019-09   2019-10   2019-11   2019-12   2020-01   2020-02  \
# ...

# %%
#drop unneeded columns and set index to Region Name
tn_sale_df = tn_sale_df.drop(columns=['Unnamed: 0', 'RegionID', 'StateName', 'SizeRank']).set_index('RegionName')
tn_sale_df
# Out:
#                2008-03   2008-04   2008-05   2008-06   2008-07   2008-08  \
# RegionName
# Memphis            NaN       NaN       NaN       NaN       NaN       NaN
# Nashville     148900.0  147200.0  146100.0  147600.0  147400.0  147400.0
# Knoxville     137000.0  137700.0  139800.0  138000.0  134900.0  134000.0
# Chattanooga   107100.0  104600.0  108500.0  106000.0  107400.0  101000.0
# Murfreesboro  140000.0  142300.0  142000.0  138700.0  134800.0  134000.0
# ...                ...       ...       ...       ...       ...       ...
# Chapel Hill        NaN       NaN       NaN       NaN       NaN       NaN
# Pigeon Forge       NaN       NaN       NaN       NaN       NaN       NaN
# Medina             NaN       NaN       NaN       NaN       NaN       NaN
# Millersville       NaN       NaN       NaN       NaN       NaN       NaN
# Gatlinburg         NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
#transpose dataframe to filter by dates
tn_transpose_df = tn_sale_df.T
tn_transpose_df
# Out:
# RegionName   Memphis  Nashville  Knoxville  Chattanooga  Murfreesboro  \
# 2008-03          NaN   148900.0   137000.0     107100.0      140000.0
# 2008-04          NaN   147200.0   137700.0     104600.0      142300.0
# 2008-05          NaN   146100.0   139800.0     108500.0      142000.0
# 2008-06          NaN   147600.0   138000.0     106000.0      138700.0
# 2008-07          NaN   147400.0   134900.0     107400.0      134800.0
# ...              ...        ...        ...          ...           ...
# 2019-11     102100.0   283700.0   185100.0     179300.0      261900.0
# 2019-12     104800.0   288000.0   188100.0     186200.0      267400.0
# 2020-01     104500.0   288900.0   193300.0     186300.0      269500.0
# 2020-02     109900.0   295500.0   202800.0     199100.0      261900.0
# 2020-03          NaN   296200.0        NaN          NaN      257900.0
#
# RegionName  Clarksville  Franklin  Johnson City  Cleveland   Jackson  ...  \
# ...

# %%
# find number of null values by region
tn_transpose_df.isnull().sum()
# Out:
# RegionName
# Memphis          23
# Nashville         0
# Knoxville         1
# Chattanooga       1
# Murfreesboro      0
#                ...
# Chapel Hill     110
# Pigeon Forge     78
# Medina           72
# Millersville    113
# Gatlinburg      120
# Length: 84, dtype: int64

# %%
sales_df = (tn_transpose_df.loc['2015-01':'2020-03'])
sales_df
# Out:
# RegionName   Memphis  Nashville  Knoxville  Chattanooga  Murfreesboro  \
# 2015-01      81900.0   179000.0   138500.0     133800.0      166800.0
# 2015-02      82500.0   180900.0   147600.0     137700.0      165400.0
# 2015-03      81800.0   180600.0   145800.0     139900.0      168700.0
# 2015-04      83300.0   182000.0   146800.0     141800.0      169700.0
# 2015-05      82700.0   184300.0   143400.0     136300.0      171500.0
# ...              ...        ...        ...          ...           ...
# 2019-11     102100.0   283700.0   185100.0     179300.0      261900.0
# 2019-12     104800.0   288000.0   188100.0     186200.0      267400.0
# 2020-01     104500.0   288900.0   193300.0     186300.0      269500.0
# 2020-02     109900.0   295500.0   202800.0     199100.0      261900.0
# 2020-03          NaN   296200.0        NaN          NaN      257900.0
#
# RegionName  Clarksville  Franklin  Johnson City  Cleveland   Jackson  ...  \
# ...

# %%
#recount null values
sales_df.isnull().sum()
# Out:
# RegionName
# Memphis          1
# Nashville        0
# Knoxville        1
# Chattanooga      1
# Murfreesboro     0
#                 ..
# Chapel Hill     28
# Pigeon Forge     0
# Medina           0
# Millersville    31
# Gatlinburg      38
# Length: 84, dtype: int64

# %%
#transpose dataframe back 
sales_df = sales_df.T
sales_df
# Out:
#                2015-01   2015-02   2015-03   2015-04   2015-05   2015-06  \
# RegionName
# Memphis        81900.0   82500.0   81800.0   83300.0   82700.0   82200.0
# Nashville     179000.0  180900.0  180600.0  182000.0  184300.0  185400.0
# Knoxville     138500.0  147600.0  145800.0  146800.0  143400.0  146700.0
# Chattanooga   133800.0  137700.0  139900.0  141800.0  136300.0  132600.0
# Murfreesboro  166800.0  165400.0  168700.0  169700.0  171500.0  172900.0
# ...                ...       ...       ...       ...       ...       ...
# Chapel Hill        NaN       NaN       NaN       NaN       NaN       NaN
# Pigeon Forge  171400.0  175300.0  149400.0  151600.0  146700.0  147100.0
# Medina        139500.0  137000.0  137600.0  140500.0  149600.0  149300.0
# Millersville       NaN       NaN       NaN       NaN       NaN       NaN
# Gatlinburg         NaN       NaN       NaN       NaN       NaN       NaN
#
# ...
